# %% [markdown]
# <img src="https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/main/media/logo/newebac_logo_black_half.png" alt="ebac-logo">
#
# ---
#
# # **Python: Projeto Final** | Análise de Dados Finaceiros e sua Relação com a Inadimplência
# Notebook do Projeto Final do curso "Python para Análise de Dados" da [Ebac](https://ebaconline.com.br/python-para-dados)<br>
# **Aluno** [Lucas Edmundo](https://www.linkedin.com/in/lucas-edmundo-m-1738b31a2)<br>
# **Professor** [André Perez](https://www.linkedin.com/in/andremarcosperez/)
#
# ---

# %% [markdown]
# # **Tópicos**
#
# <ol type="1">
#   <li>Introdução ao Problema;</li>
#   <li>Importação de Bibliotecas;</li>
#   <li>Carga dos Dados;</li>
#   <li>Exploração de Dados;</li>
#   <li>Transformação e Limpeza de Dados;</li>
#   <li>Visualização e Análise de Dados;</li>
#   <li>Resumo dos Insights.</li>
# </ol>

# %% [markdown]
# ---

# %% [markdown]
# # **Projeto**

# %% [markdown]
# ## 1\. Introdução ao Problema

# %% [markdown]
# Este projeto simula um dos diversos problemas encontrados no âmbito financeiro, sendo ele a [inadimplência](https://www.serasa.com.br/ensina/seu-nome-limpo/o-que-e-inadimplencia/), cuja preocupação está voltada para o cliente e sua situação financeira para com a empresa responsável, por exemplo, pela concessão de crédito e afins. Posto isso, este projeto contará com um processo completo de análise de dados, a fim de entender as motivações e "comportamentos" que a inadimplência apresenta.

# %% [markdown]
# > Este notebook está disponível no meu perfil no [GitHub](https://github.com/lucasedmundo11) e [Kaggle](https://www.kaggle.com/lucasedmundo), a fim de compor o meu portfólio profissional, educacional e pessoal, demonstrando meus conhecimentos, aprendizados e paixão pela tecnologia.

# %% [markdown]
# ## 2\. Importação de Bibliotecas

# %% [markdown]
# Para este projeto serão utilizadas as bibliotecas [Pandas](https://pandas.pydata.org), [Seaborn](https://seaborn.pydata.org) e [Matplotlib](https://matplotlib.org), a fim de realizar as etapas de exploração, transformação e visualização dos dados.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## 3\. Carga dos Dados

# %% [markdown]
# Serão explorados os dados de crédito presentes neste [link](https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv) e, para isso, será utilizado a função `read_csv` da biblioteca Pandas para a leitura dos dados em um dataframe. Posto isso, os valores nulos da base de dados foram reportados como valores `na` para o atributo `na_values` da função citada anteriormente.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/andre-marcos-perez/ebac-course-utils/develop/dataset/credito.csv', na_values='na')

# %% [markdown]
# ## 4\. Exploração de Dados

# %% [markdown]
# Os dados estão no formato CSV e contém informações sobre clientes de uma instituição financeira. Em especial, estamos interessados em explicar a segunda coluna, chamada de **default**, que indica se um cliente é adimplente(`default = 0`), ou inadimplente (`default = 1`), ou seja, buscamos entender o porque um cliente deixa de honrar com suas dívidas baseado no comportamento de outros atributos, como salário, escolaridade e movimentação financeira. Uma descrição completa dos atributos está abaixo.

# %% [markdown]
# > O atributo de interesse (`default`) é conhecido como **variável resposta** ou **variável dependente**, já os demais atributos que buscam explicá-la (`idade`, `salário`, etc.) são conhecidas como **variáveis explicatívas**, **variáveis independentes** ou até **variáveis preditoras**.

# %% [markdown]
# | Coluna  | Descrição |
# | ------- | --------- |
# | id      | Número da conta |
# | default | Indica se o cliente é adimplente (0) ou inadimplente (1) |
# | idade   | --- |
# | sexo    | --- |
# | depedentes | --- |
# | escolaridade | --- |
# | estado_civil | --- |
# | salario_anual | Faixa do salario mensal multiplicado por 12 |
# | tipo_cartao | Categoria do cartao: blue, silver, gold e platinium |
# | meses_de_relacionamento | Quantidade de meses desde a abertura da conta |
# | qtd_produtos | Quantidade de produtos contratados |
# | iteracoes_12m | Quantidade de iteracoes com o cliente no último ano |
# | meses_inatico_12m | Quantidade de meses que o cliente ficou inativo no último ano |
# | limite_credito | Valor do limite do cartão de crédito |
# | valor_transacoes_12m | Soma total do valor das transações no cartão de crédito no último ano |
# | qtd_transacoes_12m | Quantidade total de transações no cartão de crédito no último ano |

# %% [markdown]
# Inicialmente, serão apresentadas as `n` primeiras linhas do dataframe.

# %%
df.head(n=10)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
# 5  713061558        0     44    M            2             mestrado
# 6  810347208        0     51    M            4                  NaN
# 7  818906208        0     32    M            0         ensino medio
# 8  710930508        0     37    M            3  sem educacao formal
# 9  719661558        0     48    M            2             mestrado
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# ...

# %% [markdown]
# ### **4.1. Estrutura**

# %% [markdown]
# Com os dados já visualizados, agora entraremos na etapa de observação da estrutura dos dados, incluindo o schema e dados faltantes.

# %%
df.shape  # retorna uma tupla (qtd linhas, qtd colunas)
# Out:
# (10127, 16)

# %%
df[df['default'] == 0].shape # idem, porém, apenas, para os clientes adimplentes
# Out:
# (8500, 16)

# %%
df[df['default'] == 1].shape # idem, porém, apenas, para os clientes inadimplentes
# Out:
# (1627, 16)

# %% [markdown]
# Faremos um cálculo da porcentagem de clientes adimplentes e inadimplentes, com o intuito de observar estatisticamente a diferença entre os valores `default`.

# %%
qtd_total, _ = df.shape
qtd_adimplentes, _ = df[df['default'] == 0].shape
qtd_inadimplentes, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão clientes adimplentes é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
# Out:
# A proporcão clientes adimplentes é de 83.93%
# A proporcão clientes inadimplentes é de 16.07%

# %% [markdown]
# ### **4.2. Schema**

# %%
df.head(n=5)
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
#  - Colunas e seus respectivos tipos de dados.

# %%
df.dtypes
# Out:
# id                          int64
# default                     int64
# idade                       int64
# sexo                       object
# dependentes                 int64
# escolaridade               object
# estado_civil               object
# salario_anual              object
# tipo_cartao                object
# meses_de_relacionamento     int64
# qtd_produtos                int64
# iteracoes_12m               int64
# meses_inativo_12m           int64
# limite_credito             object
# valor_transacoes_12m       object
# qtd_transacoes_12m          int64
# dtype: object

# %% [markdown]
#  - Atributos **categóricos**.

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                       count unique             top  freq
# sexo                  10127      2               F  5358
# escolaridade           8608      5        mestrado  3128
# estado_civil           9378      3          casado  4687
# salario_anual          9015      5  menos que $40K  3561
# tipo_cartao           10127      4            blue  9436
# limite_credito        10127   9272        1.438,21    11
# valor_transacoes_12m  10127  10035        3.851,51     3

# %% [markdown]
# Como apresentado na tabela acima, os campos `limite_credito` e `valor_transacoes_12m` são reconhecidos como atributos categóricos pelo Pandas, porém erroneamente. Portanto, tais campos necessitam de correção.

# %% [markdown]
#  - Atributos **numéricos**.

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count       mean        std   min   25%   50%  \
# default                  10127.0   0.160660   0.367235   0.0   0.0   0.0
# idade                    10127.0  46.325960   8.016814  26.0  41.0  46.0
# dependentes              10127.0   2.346203   1.298908   0.0   1.0   2.0
# meses_de_relacionamento  10127.0  35.928409   7.986416  13.0  31.0  36.0
# qtd_produtos             10127.0   3.812580   1.554408   1.0   3.0   4.0
# iteracoes_12m            10127.0   2.455317   1.106225   0.0   2.0   2.0
# meses_inativo_12m        10127.0   2.341167   1.010622   0.0   2.0   2.0
# qtd_transacoes_12m       10127.0  64.858695  23.472570  10.0  45.0  67.0
#
#                           75%    max
# default                   0.0    1.0
# idade                    52.0   73.0
# dependentes               3.0    5.0
# meses_de_relacionamento  40.0   56.0
# qtd_produtos              5.0    6.0
# iteracoes_12m             3.0    6.0
# meses_inativo_12m         3.0    6.0
# ...

# %% [markdown]
# ### **4.3. Dados faltantes**

# %% [markdown]
# Conforme dito no tópico 3, os valores nulos são representados como `na` na base de dados e, nesta etapa, os mesmos serão explorados e observados.

# %%
df.head()
# Out:
#           id  default  idade sexo  dependentes         escolaridade  \
# 0  768805383        0     45    M            3         ensino medio
# 1  818770008        0     49    F            5             mestrado
# 2  713982108        0     51    M            3             mestrado
# 3  769911858        0     40    F            4         ensino medio
# 4  709106358        0     40    M            3  sem educacao formal
#
#   estado_civil   salario_anual tipo_cartao  meses_de_relacionamento  \
# 0       casado     $60K - $80K        blue                       39
# 1     solteiro  menos que $40K        blue                       44
# 2       casado    $80K - $120K        blue                       36
# 3          NaN  menos que $40K        blue                       34
# 4       casado     $60K - $80K        blue                       21
#
#    qtd_produtos  iteracoes_12m  meses_inativo_12m limite_credito  \
# 0             5              3                  1      12.691,51
# ...

# %% [markdown]
# Podemos verificar quais colunas possuem dados faltantes.

# %%
df.isna().any()
# Out:
# id                         False
# default                    False
# idade                      False
# sexo                       False
# dependentes                False
# escolaridade                True
# estado_civil                True
# salario_anual               True
# tipo_cartao                False
# meses_de_relacionamento    False
# qtd_produtos               False
# iteracoes_12m              False
# meses_inativo_12m          False
# limite_credito             False
# valor_transacoes_12m       False
# qtd_transacoes_12m         False
# dtype: bool

# %% [markdown]
#  - A função abaixo levanta algumas estatisticas sobre as colunas dos dados faltantes.

# %%
def stats_dados_faltantes(df: pd.DataFrame) -> None:

  stats_dados_faltantes = []
  for col in df.columns:
    if df[col].isna().any():
      qtd, _ = df[df[col].isna()].shape
      total, _ = df.shape
      dict_dados_faltantes = {col: {'quantidade': qtd, "porcentagem": round(100 * qtd/total, 2)}}
      stats_dados_faltantes.append(dict_dados_faltantes)

  for stat in stats_dados_faltantes:
    print(stat)

# %%
stats_dados_faltantes(df=df) # Retorna uma visão geral dos nulos na base de dados
# Out:
# {'escolaridade': {'quantidade': 1519, 'porcentagem': 15.0}}
# {'estado_civil': {'quantidade': 749, 'porcentagem': 7.4}}
# {'salario_anual': {'quantidade': 1112, 'porcentagem': 10.98}}

# %%
stats_dados_faltantes(df=df[df['default'] == 0]) # Idem para os clientes adimplentes
# Out:
# {'escolaridade': {'quantidade': 1263, 'porcentagem': 14.86}}
# {'estado_civil': {'quantidade': 620, 'porcentagem': 7.29}}
# {'salario_anual': {'quantidade': 925, 'porcentagem': 10.88}}

# %%
stats_dados_faltantes(df=df[df['default'] == 1]) # Idem para os clientes inadimplentes
# Out:
# {'escolaridade': {'quantidade': 256, 'porcentagem': 15.73}}
# {'estado_civil': {'quantidade': 129, 'porcentagem': 7.93}}
# {'salario_anual': {'quantidade': 187, 'porcentagem': 11.49}}

# %% [markdown]
# Ao analisar a porcentagem de nulos nos três casos acima, observamos que as porcentagens giram em torno de 15%, 7.5% e 11%. Portanto, a exclusão dos nulos da base de dados afetará igualmente os casos de clientes adimplentes e inadimplentes, ou seja, não alterará significativamente o resultado das análises.

# %% [markdown]
# ## 5\. Transformação e limpeza de dados

# %% [markdown]
# Agora que conhecemos melhor a natureza do nosso conjunto de dados, será realizado o *data wrangling* que consiste na transformação e limpeza dos dados do conjunto para que possam ser melhor analisados. Em especial, vamos remover:
#
#  - Corrigir o *schema* das nossas colunas;
#  - Remover os dados faltantes.

# %% [markdown]
# ### **5.1. Correção de schema**

# %% [markdown]
# Na etapa de exploração, notamos que as colunas **limite_credito** e **valor_transacoes_12m** estavam sendo interpretadas como colunas categóricas (`dtype = object`).

# %%
df[['limite_credito', 'valor_transacoes_12m']].dtypes
# Out:
# limite_credito          object
# valor_transacoes_12m    object
# dtype: object

# %%
df[['limite_credito', 'valor_transacoes_12m']].head(n=5)
# Out:
#   limite_credito valor_transacoes_12m
# 0      12.691,51             1.144,90
# 1       8.256,96             1.291,45
# 2       3.418,56             1.887,72
# 3       3.313,03             1.171,56
# 4       4.716,22               816,08

# %% [markdown]
# Vamos criar uma função `lambda` para limpar os dados. Mas antes, vamos testar sua aplicação através do método funcional `map`:

# %%
valores_originais = ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
valores_limpos = list(map(lambda valor: float(valor.replace(".", "").replace(",", ".")), valores_originais))

print(valores_originais)
print(valores_limpos)
# Out:
# ['12.691,51', '8.256,96', '3.418,56', '3.313,03', '4.716,22']
# [12691.51, 8256.96, 3418.56, 3313.03, 4716.22]

# %% [markdown]
# Com a função `lambda` de limpeza pronta, basta aplica-la nas colunas de interesse.

# %%
df['valor_transacoes_12m'] = df['valor_transacoes_12m'].apply(lambda valor: float(valor.replace(".", "").replace(",", ".")))
df['limite_credito'] = df['limite_credito'].apply(lambda valor: float(valor.replace(".", "").replace(",", ".")))

# %% [markdown]
# Descrevendo novamente o *schema*:

# %%
df.dtypes
# Out:
# id                           int64
# default                      int64
# idade                        int64
# sexo                        object
# dependentes                  int64
# escolaridade                object
# estado_civil                object
# salario_anual               object
# tipo_cartao                 object
# meses_de_relacionamento      int64
# qtd_produtos                 int64
# iteracoes_12m                int64
# meses_inativo_12m            int64
# limite_credito             float64
# valor_transacoes_12m       float64
# qtd_transacoes_12m           int64
# dtype: object

# %% [markdown]
#  - Atributos **categóricos**.

# %%
df.select_dtypes('object').describe().transpose()
# Out:
#                count unique             top  freq
# sexo           10127      2               F  5358
# escolaridade    8608      5        mestrado  3128
# estado_civil    9378      3          casado  4687
# salario_anual   9015      5  menos que $40K  3561
# tipo_cartao    10127      4            blue  9436

# %% [markdown]
#  - Atributos **numéricos**.

# %%
df.drop('id', axis=1).select_dtypes('number').describe().transpose()
# Out:
#                            count         mean          std      min       25%  \
# default                  10127.0     0.160660     0.367235     0.00     0.000
# idade                    10127.0    46.325960     8.016814    26.00    41.000
# dependentes              10127.0     2.346203     1.298908     0.00     1.000
# meses_de_relacionamento  10127.0    35.928409     7.986416    13.00    31.000
# qtd_produtos             10127.0     3.812580     1.554408     1.00     3.000
# iteracoes_12m            10127.0     2.455317     1.106225     0.00     2.000
# meses_inativo_12m        10127.0     2.341167     1.010622     0.00     2.000
# limite_credito           10127.0  8632.440165  9088.788041  1438.00  2555.355
# valor_transacoes_12m     10127.0  4404.583047  3397.128078   510.16  2155.825
# qtd_transacoes_12m       10127.0    64.858695    23.472570    10.00    45.000
#
#                              50%        75%       max
# default                     0.00      0.000      1.00
# ...

# %% [markdown]
# ### **5.2. Remoção de dados faltantes**

# %% [markdown]
# Como o pandas está ciente do que é um dado faltante, a remoção das linhas problemáticas é trivial.

# %%
df.dropna(inplace=True)

# %% [markdown]
# Analisando a estrutura dos dados novamente.

# %%
df.shape
# Out:
# (7081, 16)

# %%
df[df['default'] == 0].shape
# Out:
# (5968, 16)

# %%
df[df['default'] == 1].shape
# Out:
# (1113, 16)

# %% [markdown]
# Observando novamente as porcentagens do dataframe e comparando com as medidas calculadas anteriormente.

# %%
qtd_total_novo, _ = df.shape
qtd_adimplentes_novo, _ = df[df['default'] == 0].shape
qtd_inadimplentes_novo, _ = df[df['default'] == 1].shape

# %%
print(f"A proporcão adimplentes ativos é de {round(100 * qtd_adimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes adimplentes é de {round(100 * qtd_adimplentes_novo / qtd_total_novo, 2)}%")
print("")
print(f"A proporcão clientes inadimplentes é de {round(100 * qtd_inadimplentes / qtd_total, 2)}%")
print(f"A nova proporcão de clientes inadimplentes é de {round(100 * qtd_inadimplentes_novo / qtd_total_novo, 2)}%")
# Out:
# A proporcão adimplentes ativos é de 83.93%
# A nova proporcão de clientes adimplentes é de 84.28%
#
# A proporcão clientes inadimplentes é de 16.07%
# A nova proporcão de clientes inadimplentes é de 15.72%

# %% [markdown]
# ## 6\. Visualização e Análise de dados

# %% [markdown]
# Com os dados já preparados, serão criadas diversas visualizações para correlacionar variáveis explicativas com a variável resposta para buscar entender qual fator leva um cliente a inadimplência. Posto isso, vamos sempre comparar a base com todos os clientes com a base de adimplentes e inadimplentes.

# %% [markdown]
# Começamos, então, utilizando os pacotes de visualização e separando os clientes adimplentes e inadimplentes

# %%
sns.set_style("whitegrid")

# %%
df_adimplente = df[df['default'] == 0]

# %%
df_inadimplente = df[df['default'] == 1]

# %% [markdown]
# ### **6.1. Visualizações categóricas**

# %% [markdown]
# Nesta seção, vamos visualizar a relação entre a variável resposta `default` com os atributos categóricos.

# %%
df.select_dtypes('object').head(n=5)
# Out:
#   sexo         escolaridade estado_civil   salario_anual tipo_cartao
# 0    M         ensino medio       casado     $60K - $80K        blue
# 1    F             mestrado     solteiro  menos que $40K        blue
# 2    M             mestrado       casado    $80K - $120K        blue
# 4    M  sem educacao formal       casado     $60K - $80K        blue
# 5    M             mestrado       casado     $40K - $60K        blue

# %% [markdown]
#  - Escolaridade

# %%
coluna = 'escolaridade'
titulos = ['Escolaridade dos Clientes', 'Escolaridade dos Clientes Adimplentes', 'Escolaridade dos Clientes Inadimplentes']

eixo = 0
max_y = 0
max = df.select_dtypes('object').describe()[coluna]['freq'] * 1.1

figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

# %% [markdown]
#  - Salário Anual

# %%
coluna = 'salario_anual'
titulos = ['Salário Anual dos Clientes', 'Salário Anual dos Clientes Adimplentes', 'Salário Anual dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index
  df_to_plot.reset_index(inplace=True, drop=True)

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))
  eixo += 1

# %% [markdown]
# - Tipo de Cartão

# %%
coluna = 'tipo_cartao'
titulos = ['Tipo de Cartão dos Clientes', 'Tipo de Cartão dos Clientes Adimplentes', 'Tipo de Cartão dos Clientes Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  df_to_plot = dataframe[coluna].value_counts().to_frame()
  df_to_plot.rename(columns={coluna: 'frequencia_absoluta'}, inplace=True)
  df_to_plot[coluna] = df_to_plot.index
  df_to_plot.reset_index(inplace=True, drop=True)

  f = sns.barplot(x=df_to_plot[coluna], y=df_to_plot['frequencia_absoluta'], ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')
  f.set_xticklabels(labels=f.get_xticklabels(), rotation=90)
  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))
  eixo += 1

# %% [markdown]
# **Insight:** Ao analisar os gráficos dos atributos categóricos, percebe-se que em todos os atributos e relações apresentadas manteve-se a proporção entre as labels, ou seja, não demonstra um aspecto relevante para o comportamento do `default`.

# %% [markdown]
# ### **6.2. Visualizações numéricas**

# %% [markdown]
# Nesta seção, vamos visualizar a relação entre a variável resposta **default** com os atributos numéricos.

# %%
df.drop(['id', 'default'], axis=1).select_dtypes('number').head(n=5)
# Out:
#    idade  dependentes  meses_de_relacionamento  qtd_produtos  iteracoes_12m  \
# 0     45            3                       39             5              3
# 1     49            5                       44             6              2
# 2     51            3                       36             4              0
# 4     40            3                       21             5              0
# 5     44            2                       36             3              2
#
#    meses_inativo_12m  limite_credito  valor_transacoes_12m  qtd_transacoes_12m
# 0                  1        12691.51               1144.90                  42
# 1                  1         8256.96               1291.45                  33
# 2                  1         3418.56               1887.72                  20
# 4                  1         4716.22                816.08                  28
# 5                  1         4010.69               1088.07                  24

# %% [markdown]
#  - Quantidade de Transações nos Últimos 12 Meses

# %%
coluna = 'qtd_transacoes_12m'
titulos = ['Qtd. de Transações no Último Ano', 'Qtd. de Transações no Último Ano de Adimplentes', 'Qtd. de Transações no Último Ano de Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

# %% [markdown]
# **Insight:** A diferença encontrada no intervalo de 20 a 60 na label `Qtd_transacoes_12m` entre os gráficos adimplentes e inadimplentes pode representar uma conclusão relevante para o default. Deste modo, os clientes com o número de transações no intervalo entre 20 e 60 no período dos últimos 12 meses podem futuramente apresentar inadimplência. Portante, uma possível ação a ser realizada é um acompanhamento personalizado com mais iterações com tais clientes.

# %% [markdown]
#  - Valor das Transações nos Últimos 12 Meses

# %%
coluna = 'valor_transacoes_12m'
titulos = ['Valor das Transações no Último Ano', 'Valor das Transações no Último Ano de Adimplentes', 'Valor das Transações no Último Ano de Inadimplentes']

eixo = 0
max_y = 0
figura, eixos = plt.subplots(1,3, figsize=(20, 5), sharex=True)

for dataframe in [df, df_adimplente, df_inadimplente]:

  f = sns.histplot(x=coluna, data=dataframe, stat='count', ax=eixos[eixo])
  f.set(title=titulos[eixo], xlabel=coluna.capitalize(), ylabel='Frequência Absoluta')

  _, max_y_f = f.get_ylim()
  max_y = max_y_f if max_y_f > max_y else max_y
  f.set(ylim=(0, max_y))

  eixo += 1

# %% [markdown]
# **Insight:** Partindo dos gráficos apresentados acima, o comportamento dos clientes inadimplentes tende a se concentrar no valor de transações próximo a 2500, contrastando com o intervalo entre, aproximadamente, 500 e 5000 dos clientes adimplentes.

# %% [markdown]
#  - Valor de Transações nos Últimos 12 Meses x Quantidade de Transações nos Últimos 12 Meses

# %%
f = sns.relplot(x='valor_transacoes_12m', y='qtd_transacoes_12m', data=df, hue='default')
_ = f.set(
    title='Relação entre Valor e Quantidade de Transações no Último Ano', 
    xlabel='Valor das Transações no Último Ano', 
    ylabel='Quantidade das Transações no Último Ano'
  )

# %% [markdown]
# **Insight:** A representação deste gráfico expõe explicitamente dois grupos de `default` representados com a cor laranja (clientes inadimplentes), sendo o primeiro na zona 0-5000 e o segundo 7500-10000, utilizando como referência o campo `valor_transacoes_12m`. Deste modo, os esforços devem se concentrar nos clientes que possuem um número razoável de transações com valores abaixo da média ou que possuem muitas transações com valor dentro da média.

# %% [markdown]
# ## 7\. Resumo dos Insights

# %% [markdown]
# A partir dos insights obtidos anteriormente no tópico 6, conclui-se que dentre os clientes indimplentes encontrados durante as análise do dataframe e seus gráficos há dois perfis sendo eles:

# %% [markdown]
# >**A:** Clientes que realizaram de 20 a 60 transações em 12 meses, sendo estas transações pertencentes ao intervalo de 0 a 5000;<br>
# **B:** Clientes que realizaram, aproximadamente, de 50 a 90 transações em 12 meses, sendo estas transações pertencentes ao intervalo de 7500 a 10000.

# %% [markdown]
# Deste modo, é recomendável que clientes que se encaixem nos perfis explicitados sejam acompanhados de forma mais acertiva e
# com iterações mrecorrentes, a fim de ajudar e obter feedbacks do cliente quanto a sua situação financeira, ajudando-o a evitar ou sair do quadro de inadimplência.

# %% [markdown]
# ____

# %% [markdown]
# Obrigado por chegado até aqui, espero que tenha gostado deste notebook! Caso possua dúvidas sobre o projeto, recomendações ou dicas, estarei disponível no meu [LinkedIn](https://www.linkedin.com/in/lucas-edmundo-m-1738b31a2).
#
# Até a próxima :)
